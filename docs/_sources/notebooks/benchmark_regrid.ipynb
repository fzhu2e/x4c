# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir('/glade/u/home/fengzhu/Github/x4c/docsrc/notebooks')
import numpy as np
import x4c
print(x4c.__version__)
# Out:
# 2024.5.15

# %%
ds_old = x4c.open_dataset('/glade/campaign/univ/ubrn0018/fengzhu/CESM_output/timeseries/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.005.offset.d18O.branch/atm/proc/tseries/month_1/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.005.offset.d18O.branch.cam.h0.TS.200101-205012.nc')
ds_old
# Out:
# <xarray.Dataset>
# Dimensions:       (lev: 30, ilev: 31, ncol: 13826, time: 600, nbnd: 2)
# Coordinates:
#   * lev           (lev) float64 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * ilev          (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * time          (time) object 2001-02-01 00:00:00 ... 2051-01-01 00:00:00
# Dimensions without coordinates: ncol, nbnd
# Data variables: (12/31)
#     hyam          (lev) float64 ...
#     hybm          (lev) float64 ...
#     P0            float64 ...
#     hyai          (ilev) float64 ...
#     hybi          (ilev) float64 ...
#     lat           (ncol) float64 ...
#     ...            ...
#     n2ovmr        (time) float64 ...
#     f11vmr        (time) float64 ...
#     f12vmr        (time) float64 ...
#     sol_tsi       (time) float64 ...
#     nsteph        (time) int32 ...
#     TS            (time, ncol) float32 ...
# Attributes: (12/13)
#     np:               4
#     ne:               16
#     Conventions:      CF-1.0
#     source:           CAM
#     case:             b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5x...
#     title:            UNSET
#     ...               ...
#     host:             derecho4
#     Version:          $Name$
#     revision_Id:      $Id$
#     initial_file:     /glade/campaign/cesm/cesmdata/inputdata/atm/cam/inic/ho...
#     topography_file:  /glade/work/fengzhu/Projects/Miocene-on-Derecho/04.atm-...
#     path:             /glade/campaign/univ/ubrn0018/fengzhu/CESM_output/times...

# %%
dirpath = '/glade/campaign/univ/ubrn0018/fengzhu/CESM_output/timeseries/test'
fname = 'b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005.offset.d18O.branch.cam.h0.TS.750101-750112.nc'
case = x4c.Timeseries(dirpath)
# Out:
# >>> case.root_dir: /glade/campaign/univ/ubrn0018/fengzhu/CESM_output/timeseries/test
# >>> case.path_pattern: comp/proc/tseries/month_1/casename.mdl.h_str.vn.timespan.nc
# >>> case.grid_dict: {'atm': 'ne16', 'ocn': 'g16', 'lnd': 'ne16', 'rof': 'ne16', 'ice': 'g16'}
# >>> case.vars_info created

# %%
ds = x4c.load_dataset(os.path.join(dirpath, fname))
ds['TS']
# Out:
# <xarray.DataArray 'TS' (time: 12, ncol: 13826)>
# array([[303.56992, 303.07846, 302.40677, ..., 293.71167, 291.00327,
#         291.70682],
#        [305.134  , 304.67032, 303.87808, ..., 292.52054, 290.49017,
#         291.22662],
#        [304.73544, 304.35202, 303.7073 , ..., 292.15277, 291.44006,
#         292.1198 ],
#        ...,
#        [297.93823, 296.90848, 295.77628, ..., 302.2056 , 300.0421 ,
#         300.95715],
#        [299.1052 , 298.08023, 296.97968, ..., 298.1864 , 295.89523,
#         296.68027],
#        [301.75415, 301.02145, 300.07892, ..., 294.88278, 292.3789 ,
#         293.29907]], dtype=float32)
# Coordinates:
#   * time     (time) object 7501-02-01 00:00:00 ... 7502-01-01 00:00:00
# Dimensions without coordinates: ncol
# Attributes:
#     units:         K
#     long_name:     Surface temperature (radiative)
#     cell_methods:  time: mean
