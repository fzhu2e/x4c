# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir('/glade/u/home/fengzhu/Github/x4c/docsrc/notebooks')
import numpy as np
import x4c
import xarray as xr
print(x4c.__version__)
# Out:
# 2024.5.15

# %% [markdown]
# ## Sample Data

# %% [markdown]
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_ANN_climo.nc
#     - climatology of annual
#
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_DJF_climo.nc
#     - climatology of DJF
#
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_JJA_climo.nc
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_MAM_climo.nc
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_SON_climo.nc
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_MONS_climo.nc
#     - climatology of each month?
#
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_ANN_means.nc
#     - annual mean of each year
#
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_DJF_means.nc
#     - DJF mean of each year
#
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_JJA_means.nc
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_MAM_means.nc
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_SON_means.nc
#
# - b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_ANN_ALL.nc
#     - timeseries for all variables

# %%
sample_dirpath = '/glade/derecho/scratch/fengzhu/b.e23_alpha17f.BLT1850.ne30_t232.092_15_24'

# %%
fname = 'b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_MONS_climo.nc'
ds = x4c.open_dataset(os.path.join(sample_dirpath, fname))
ds
# Out:
# <xarray.Dataset>
# Dimensions:                        (lat: 192, lon: 288, levgrnd: 25,
#                                     levsoi: 20, levlak: 10, levdcmp: 25,
#                                     time: 12, cft: 64, glc_nec: 10, ltype: 9,
#                                     natpft: 15, nvegwcs: 4)
# Coordinates:
#   * lat                            (lat) float32 -90.0 -89.06 ... 89.06 90.0
#   * lon                            (lon) float32 0.0 1.25 2.5 ... 357.5 358.8
#   * levgrnd                        (levgrnd) float32 0.01 0.04 ... 28.87 42.0
#   * levsoi                         (levsoi) float32 0.01 0.04 0.09 ... 6.94 8.03
#   * levlak                         (levlak) float32 0.05 0.6 2.1 ... 34.33 44.78
#   * levdcmp                        (levdcmp) float32 0.01 0.04 ... 28.87 42.0
#   * time                           (time) object 0019-08-02 12:00:00 ... 0020...
# Dimensions without coordinates: cft, glc_nec, ltype, natpft, nvegwcs
# Data variables: (12/541)
# ...

# %%
fname = 'b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_ANN_ALL.nc'
ds = x4c.open_dataset(os.path.join(sample_dirpath, fname))
ds
# Out:
# <xarray.Dataset>
# Dimensions:                        (lat: 192, lon: 288, levgrnd: 25,
#                                     levsoi: 20, levlak: 10, levdcmp: 25,
#                                     time: 24, cft: 64, glc_nec: 10, ltype: 9,
#                                     natpft: 15, nvegwcs: 4)
# Coordinates:
#   * lat                            (lat) float32 -90.0 -89.06 ... 89.06 90.0
#   * lon                            (lon) float32 0.0 1.25 2.5 ... 357.5 358.8
#   * levgrnd                        (levgrnd) float32 0.01 0.04 ... 28.87 42.0
#   * levsoi                         (levsoi) float32 0.01 0.04 0.09 ... 6.94 8.03
#   * levlak                         (levlak) float32 0.05 0.6 2.1 ... 34.33 44.78
#   * levdcmp                        (levdcmp) float32 0.01 0.04 ... 28.87 42.0
#   * time                           (time) object 0001-07-17 17:17:35.566406 ....
# Dimensions without coordinates: cft, glc_nec, ltype, natpft, nvegwcs
# Data variables: (12/540)
# ...

# %%
fname = 'b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_ANN_means.nc'
ds = xr.open_dataset(os.path.join(sample_dirpath, fname))
ds
# Out:
# <xarray.Dataset>
# Dimensions:                        (lat: 192, lon: 288, levgrnd: 25,
#                                     levsoi: 20, levlak: 10, levdcmp: 25,
#                                     time: 10, cft: 64, glc_nec: 10, ltype: 9,
#                                     natpft: 15, nvegwcs: 4)
# Coordinates:
#   * lat                            (lat) float32 -90.0 -89.06 ... 89.06 90.0
#   * lon                            (lon) float32 0.0 1.25 2.5 ... 357.5 358.8
#   * levgrnd                        (levgrnd) float32 0.01 0.04 ... 28.87 42.0
#   * levsoi                         (levsoi) float32 0.01 0.04 0.09 ... 6.94 8.03
#   * levlak                         (levlak) float32 0.05 0.6 2.1 ... 34.33 44.78
#   * levdcmp                        (levdcmp) float32 0.01 0.04 ... 28.87 42.0
#   * time                           (time) object 0015-07-17 17:17:48.750000 ....
# Dimensions without coordinates: cft, glc_nec, ltype, natpft, nvegwcs
# Data variables: (12/540)
# ...

# %%
fname = 'b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_DJF_means.nc'
ds = x4c.open_dataset(os.path.join(sample_dirpath, fname))
ds
# Out:
# <xarray.Dataset>
# Dimensions:                        (lat: 192, lon: 288, levgrnd: 25,
#                                     levsoi: 20, levlak: 10, levdcmp: 25,
#                                     time: 10, cft: 64, glc_nec: 10, ltype: 9,
#                                     natpft: 15, nvegwcs: 4)
# Coordinates:
#   * lat                            (lat) float32 -90.0 -89.06 ... 89.06 90.0
#   * lon                            (lon) float32 0.0 1.25 2.5 ... 357.5 358.8
#   * levgrnd                        (levgrnd) float32 0.01 0.04 ... 28.87 42.0
#   * levsoi                         (levsoi) float32 0.01 0.04 0.09 ... 6.94 8.03
#   * levlak                         (levlak) float32 0.05 0.6 2.1 ... 34.33 44.78
#   * levdcmp                        (levdcmp) float32 0.01 0.04 ... 28.87 42.0
#   * time                           (time) object 0015-01-30 00:47:48.750000 ....
# Dimensions without coordinates: cft, glc_nec, ltype, natpft, nvegwcs
# Data variables: (12/540)
# ...

# %% [markdown]
# ## Production

# %% [markdown]
# ### climo

# %%
climo_root='/glade/campaign/univ/ubrn0018/fengzhu/CESM_output/climo'
casename='b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002'

# %%
case = x4c.Climo(os.path.join(climo_root, casename), casename=casename)
# Out:
# >>> case.root_dir: /glade/campaign/univ/ubrn0018/fengzhu/CESM_output/climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002
# >>> case.casename: b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002

# %%
# %%time
output_dirpath = '/glade/campaign/univ/ubrn0018/fengzhu/CESM_output/combined_climo'
case.gen_MONS_climo(output_dirpath=os.path.join(output_dirpath, casename))
# Out:
# >>> output directory created at: /glade/campaign/univ/ubrn0018/fengzhu/CESM_output/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002
# >>> MONS_climo generated at: /glade/campaign/univ/ubrn0018/fengzhu/CESM_output/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_MONS_climo.nc
# CPU times: user 4min 8s, sys: 58 s, total: 5min 6s
# Wall time: 19min 6s

# %%
# %%time
case.gen_seasons_climo()
# Out:
# >>> ANN_climo generated at: /glade/campaign/univ/ubrn0018/fengzhu/CESM_output/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_ANN_climo.nc
# >>> DJF_climo generated at: /glade/campaign/univ/ubrn0018/fengzhu/CESM_output/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_DJF_climo.nc
# >>> MAM_climo generated at: /glade/campaign/univ/ubrn0018/fengzhu/CESM_output/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_MAM_climo.nc
# >>> JJA_climo generated at: /glade/campaign/univ/ubrn0018/fengzhu/CESM_output/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_JJA_climo.nc
# ...

# %%
# %%time
case.gen_seasons_climo(MONS_climo_path='/glade/derecho/scratch/fengzhu/share/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_MONS_climo.nc')
# Out:
# >>> ANN_climo generated at: /glade/derecho/scratch/fengzhu/share/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_ANN_climo.nc
# >>> DJF_climo generated at: /glade/derecho/scratch/fengzhu/share/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_DJF_climo.nc
# >>> MAM_climo generated at: /glade/derecho/scratch/fengzhu/share/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_MAM_climo.nc
# >>> JJA_climo generated at: /glade/derecho/scratch/fengzhu/share/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_JJA_climo.nc
# >>> SON_climo generated at: /glade/derecho/scratch/fengzhu/share/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_SON_climo.nc
# CPU times: user 6.45 s, sys: 1.54 s, total: 7.99 s
# Wall time: 9.57 s

# %%
ds = xr.open_dataset('/glade/derecho/scratch/fengzhu/share/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_ANN_climo.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 1, lon: 360, lat: 180, levgrnd: 15,
#                                 levlak: 10)
# Coordinates:
#   * lon                        (lon) float64 0.5 1.5 2.5 ... 357.5 358.5 359.5
#   * lat                        (lat) float64 -89.5 -88.5 -87.5 ... 88.5 89.5
#   * levgrnd                    (levgrnd) float32 0.007101 0.02792 ... 35.18
#   * levlak                     (levlak) float32 0.05 0.6 2.1 ... 34.33 44.78
#   * time                       (time) int64 1
# Data variables: (12/279)
#     mcdate                     (time) float64 ...
#     mcsec                      (time) float64 ...
#     mdcur                      (time) float64 ...
#     mscur                      (time) float64 ...
#     nstep                      (time) float64 ...
#     area                       (time, lat, lon) float32 ...
#     ...                         ...
#     WA                         (time, lat, lon) float32 ...
# ...

# %%
ds['BCDEP']
# Out:
# <xarray.DataArray 'BCDEP' (time: 1, lat: 180, lon: 360)>
# [64800 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * time     (time) int64 1
# Attributes:
#     long_name:     total BC deposition (dry+wet) from atmosphere
#     units:         kg/m^2/s
#     cell_methods:  time: mean

# %%
fpath = '/glade/derecho/scratch/oleson/ANALYSIS/climo/b.e23_alpha17f.BLT1850.ne30_t232.092_15_24/b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_JJA_climo.nc'
ds = xr.open_dataset(fpath)
ds['BCDEP']
# Out:
# <xarray.DataArray 'BCDEP' (time: 1, lat: 192, lon: 288)>
# [55296 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float32 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float32 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time     (time) object 0020-01-30 20:05:09.375000
# Attributes:
#     landunit_mask:  unknown
#     cell_methods:   time: mean
#     units:          kg/m^2/s
#     long_name:      total BC deposition (dry+wet) from atmosphere

# %% [markdown]
# ### means

# %%
ts_root='/glade/campaign/cgd/ppc/brady/paleoweather/timeseries'
casename='b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002'
case = x4c.Timeseries(os.path.join(ts_root, casename), casename=casename, grid_dict={'atm': 'ne120', 'ocn': 't12'})
# Out:
# >>> case.root_dir: /glade/campaign/cgd/ppc/brady/paleoweather/timeseries/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002
# >>> case.path_pattern: comp/proc/tseries/month_1/casename.mdl.h_str.vn.timespan.nc
# >>> case.grid_dict: {'atm': 'ne120', 'ocn': 't12', 'lnd': 'ne120', 'rof': 'ne120', 'ice': 't12'}
# >>> case.casename: b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002
# >>> case.vars_info created

# %%
# %%time
output_dirpath = '/glade/campaign/univ/ubrn0018/fengzhu/CESM_output/means'
case.save_means(
    vn='ZWT',
    comp='lnd',
    output_dirpath=os.path.join(output_dirpath, case.casename),
    timespan=(23, 50),
    adjust_month=True,
    overwrite=True,
    regrid=True,
)
# Out:
# CPU times: user 5min 27s, sys: 25.1 s, total: 5min 52s
# Wall time: 1min 2s

# %% [markdown]
# ## Merge means

# %%
root_dir = '/glade/derecho/scratch/fengzhu/x4c/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002/means'
case = x4c.Means(root_dir)
# Out:
# >>> case.root_dir: /glade/derecho/scratch/fengzhu/x4c/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002/means

# %%
# %%time
sn = 'MAM'
case.merge_means(sn, root_dir, overwrite=False, casetag='b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50')
# Out:
# >>> Processing season MAM
# >>> Merging files
# >>> Merged mean file saved at: /glade/derecho/scratch/fengzhu/x4c/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002/means/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_MAM_means.nc
# CPU times: user 3min 43s, sys: 59min 3s, total: 1h 2min 47s
# Wall time: 1h 9min 30s

# %%
# %%time
sn = 'SON'
case.merge_means(sn, root_dir, overwrite=False, casetag='b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50')
# Out:
# >>> Processing season SON
# >>> Merging files
# >>> Merged mean file saved at: /glade/derecho/scratch/fengzhu/x4c/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002/means/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_SON_means.nc
# CPU times: user 3min 36s, sys: 36min 51s, total: 40min 28s
# Wall time: 45min 43s

# %%
# %%time
# for sn in ['ANN', 'DJF', 'JJA', 'MAM', 'SON']:
#     case.merge_means(sn, root_dir, overwrite=False, casetag='b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50')

# %% [markdown]
# ## Check variable dims

# %%
sample_dirpath = '/glade/derecho/scratch/fengzhu/b.e23_alpha17f.BLT1850.ne30_t232.092_15_24'
fname = 'b.e23_alpha17f.BLT1850.ne30_t232.092_15_24_MONS_climo.nc'
ds = x4c.open_dataset(os.path.join(sample_dirpath, fname))
ds
# Out:
# <xarray.Dataset>
# Dimensions:                        (lat: 192, lon: 288, levgrnd: 25,
#                                     levsoi: 20, levlak: 10, levdcmp: 25,
#                                     time: 12, cft: 64, glc_nec: 10, ltype: 9,
#                                     natpft: 15, nvegwcs: 4)
# Coordinates:
#   * lat                            (lat) float32 -90.0 -89.06 ... 89.06 90.0
#   * lon                            (lon) float32 0.0 1.25 2.5 ... 357.5 358.8
#   * levgrnd                        (levgrnd) float32 0.01 0.04 ... 28.87 42.0
#   * levsoi                         (levsoi) float32 0.01 0.04 0.09 ... 6.94 8.03
#   * levlak                         (levlak) float32 0.05 0.6 2.1 ... 34.33 44.78
#   * levdcmp                        (levdcmp) float32 0.01 0.04 ... 28.87 42.0
#   * time                           (time) object 0019-08-02 12:00:00 ... 0020...
# Dimensions without coordinates: cft, glc_nec, ltype, natpft, nvegwcs
# Data variables: (12/541)
# ...

# %%
ds = xr.open_dataset('/glade/derecho/scratch/fengzhu/share/combined_climo/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002/b.e13.B1850C5.ne120_t12.icesm13_ihesp.PI.002_23_50_SON_means.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 28, lon: 360, lat: 180, levgrnd: 15,
#                                 levlak: 10)
# Coordinates:
#   * time                       (time) object 0023-11-30 00:00:00 ... 0050-11-...
#   * lon                        (lon) float64 0.5 1.5 2.5 ... 357.5 358.5 359.5
#   * lat                        (lat) float64 -89.5 -88.5 -87.5 ... 88.5 89.5
#   * levgrnd                    (levgrnd) float32 0.007101 0.02792 ... 35.18
#   * levlak                     (levlak) float32 0.05 0.6 2.1 ... 34.33 44.78
# Data variables: (12/280)
#     mcdate                     (time) float64 ...
#     mcsec                      (time) float64 ...
#     mdcur                      (time) float64 ...
#     mscur                      (time) float64 ...
#     nstep                      (time) float64 ...
#     area                       (time, lat, lon) float32 ...
#     ...                         ...
# ...

# %%
ds = xr.open_dataset('/glade/campaign/univ/ubrn0018/fengzhu/CESM_output/timeseries/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005/lnd/proc/tseries/month_1/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005.clm2.h0.RCELLSHA_H218O.500101-505012.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (levgrnd: 15, levlak: 10, lndgrid: 13826, time: 600,
#                      hist_interval: 2)
# Coordinates:
#   * levgrnd         (levgrnd) float32 0.007101 0.02792 0.06226 ... 21.33 35.18
#   * levlak          (levlak) float32 0.05 0.6 2.1 4.6 ... 18.6 25.6 34.33 44.78
#   * time            (time) object 5001-02-01 00:00:00 ... 5051-01-01 00:00:00
# Dimensions without coordinates: lndgrid, hist_interval
# Data variables: (12/22)
#     lon             (lndgrid) float32 ...
#     lat             (lndgrid) float32 ...
#     area            (lndgrid) float32 ...
#     topo            (lndgrid) float32 ...
#     landfrac        (lndgrid) float32 ...
#     landmask        (lndgrid) float64 ...
#     ...              ...
#     mscur           (time) int32 ...
#     nstep           (time) int32 ...
#     time_bounds     (time, hist_interval) object ...
#     date_written    (time) |S8 ...
#     time_written    (time) |S8 ...
# ...
