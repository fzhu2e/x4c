# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir('/glade/u/home/fengzhu/Github/x4c/docsrc/notebooks')
import numpy as np
import x4c
print(x4c.__version__)
# Out:
# 2024.5.14

# %% [markdown]
# ## SE2

# %%
dirpath = '/glade/campaign/univ/ubrn0018/fengzhu/CESM_output/timeseries/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005'
case = x4c.Timeseries(dirpath)
# Out:
# >>> case.root_dir: /glade/campaign/univ/ubrn0018/fengzhu/CESM_output/timeseries/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005
# >>> case.path_pattern: comp/proc/tseries/month_1/casename.mdl.h_str.vn.timespan.nc
# >>> case.grid_dict: {'atm': 'ne16', 'ocn': 'g16', 'lnd': 'ne16', 'rof': 'ne16', 'ice': 'g16'}
# >>> case.vars_info created

# %%
# %%time
casename = 'b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo',
    casename=casename,
    timespan=(6901, 7000),
    # vns=['TS', 'U', 'V'],
    comp='atm',
    nproc=16,
    overwrite=True,
    regrid=True,
)
# Out:
# >>> Generating climo for 184 variables:
# ['ADRAIN', 'ADSNOW', 'AEROD_v', 'ANRAIN', 'ANSNOW', 'AODDUST1', 'AODDUST3', 'AODVIS', 'AQRAIN', 'AQSNOW']
# ['AREI', 'AREL', 'AWNC', 'AWNI', 'BURDEN1', 'BURDEN2', 'BURDEN3', 'BURDENBC', 'BURDENDUST', 'BURDENPOM']
# ['BURDENSEASALT', 'BURDENSO4', 'BURDENSOA', 'CCN3', 'CDNUMC', 'CLDHGH', 'CLDICE', 'CLDLIQ', 'CLDLOW', 'CLDMED']
# ['CLDTOT', 'CLOUD', 'DCQ', 'DMS_SRF', 'DTCOND', 'DTV', 'DTWR_H2O2', 'DTWR_H2SO4', 'DTWR_SO2', 'FICE']
# ['FLDS', 'FLNS', 'FLNSC', 'FLNT', 'FLNTC', 'FLUT', 'FLUTC', 'FREQI', 'FREQL', 'FREQR']
# ['FREQS', 'FSDS', 'FSDSC', 'FSNS', 'FSNSC', 'FSNT', 'FSNTC', 'FSNTOA', 'FSNTOAC', 'FSUTOA']
# ['H216OI', 'H216OL', 'H216OR', 'H216OS', 'H216OV', 'H216Or', 'H216Os', 'H218OI', 'H218OL', 'H218OR']
# ['H218OS', 'H218OV', 'H218Or', 'H218Os', 'H2O2_SRF', 'H2OI', 'H2OL', 'H2OR', 'H2OS', 'H2OV']
# ['H2Or', 'H2Os', 'H2SO4_SRF', 'HDOI', 'HDOL', 'HDOR', 'HDOS', 'HDOV', 'HDOr', 'HDOs']
# ['ICEFRAC', 'ICIMR', 'ICWMR', 'IVT', 'IWC', 'LANDFRAC', 'LHFLX', 'LWCF', 'NUMICE', 'NUMLIQ']
# ['OCNFRAC', 'OMEGA', 'OMEGAT', 'PBLH', 'PHIS', 'PRECC', 'PRECL', 'PRECRC_H216Or', 'PRECRC_H218Or', 'PRECRC_H2Or']
# ['PRECRC_HDOr', 'PRECRL_H216OR', 'PRECRL_H218OR', 'PRECRL_H2OR', 'PRECRL_HDOR', 'PRECSC', 'PRECSC_H216Os', 'PRECSC_H218Os', 'PRECSC_H2Os', 'PRECSC_HDOs']
# ['PRECSL', 'PRECSL_H216OS', 'PRECSL_H218OS', 'PRECSL_H2OS', 'PRECSL_HDOS', 'PS', 'PSL', 'Q', 'QFLX', 'QRAINC']
# ['QRAINS', 'QREFHT', 'QRL', 'QRS', 'QSNOWC', 'QSNOWS', 'RELHUM', 'SHFLX', 'SNOWHICE', 'SNOWHLND']
# ['SO2_SRF', 'SOAG_SRF', 'SOLIN', 'SWCF', 'T', 'TAUGWX', 'TAUGWY', 'TAUX', 'TAUY', 'TGCLDCWP']
# ['TGCLDIWP', 'TGCLDLWP', 'TMQ', 'TREFHT', 'TS', 'TSMN', 'TSMX', 'U', 'U10', 'UU']
# ['V', 'VD01', 'VQ', 'VT', 'VU', 'VV', 'WGUSTD', 'WSUB', 'Z3', 'bc_a1_SRF']
# ['dst_a1_SRF', 'dst_a3_SRF', 'ncl_a1_SRF', 'ncl_a2_SRF', 'ncl_a3_SRF', 'num_a1_SRF', 'num_a2_SRF', 'num_a3_SRF', 'pom_a1_SRF', 'so4_a1_SRF']
# ['so4_a2_SRF', 'so4_a3_SRF', 'soa_a1_SRF', 'soa_a2_SRF']
# >>> nproc: 16
# Generating climo files: 100%|██████████| 184/184 [01:09<00:00,  2.65it/s]
# >>> 184 climo files created in: /glade/derecho/scratch/fengzhu/ADF/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005/climo
# CPU times: user 2.99 s, sys: 669 ms, total: 3.66 s
# Wall time: 1min 32s

# %%
# %%time
casename = 'b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo',
    casename=casename,
    timespan=(6901, 7000),
    vns=['TS', 'U', 'V'],
    comp='atm',
    nproc=3,
    overwrite=True,
)

# %%
# %%time
casename = 'b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo',
    casename=casename,
    timespan=(6501, 7000),
    vns=['TS', 'U', 'V'],
    comp='atm',
    nproc=1,
    overwrite=True,
)

# %%
# %%time
casename = 'b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo',
    casename=casename,
    timespan=(6501, 7000),
    vns=['TS', 'U', 'V'],
    comp='atm',
    nproc=3,
    overwrite=True,
)

# %%
# %%time
casename = 'b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.3xCO2.005'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo',
    casename=casename,
    timespan=(6901, 7000),
    comp='atm',
    nproc=16,
)

# %% [markdown]
# ## SE1

# %%
dirpath = '/glade/campaign/cgd/ppc/jiangzhu/iCESM1.3_hires/b.e13.B1850C5.ne30_g16.icesm13_ihesp.PI.002'
case = x4c.Timeseries(dirpath, grid_dict={'atm': 'ne30'})
# Out:
# >>> case.root_dir: /glade/campaign/cgd/ppc/jiangzhu/iCESM1.3_hires/b.e13.B1850C5.ne30_g16.icesm13_ihesp.PI.002
# >>> case.path_pattern: comp/proc/tseries/month_1/casename.mdl.h_str.vn.timespan.nc
# >>> case.grid_dict: {'atm': 'ne30', 'ocn': 'g16', 'lnd': 'ne30', 'rof': 'ne30', 'ice': 'g16'}
# >>> case.vars_info created

# %%
# %%time
casename = 'b.e13.B1850C5.ne30_g16.icesm13_ihesp.PI.002'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo',
    casename=casename,
    timespan=(1, 500),
    vns=['TS', 'U', 'V'],
    comp='atm',
    nproc=1,
    overwrite=True,
)

# %%
# %%time
casename = 'b.e13.B1850C5.ne30_g16.icesm13_ihesp.PI.002'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo',
    casename=casename,
    timespan=(1, 500),
    vns=['TS', 'U', 'V'],
    comp='atm',
    nproc=3,
    overwrite=True,
)

# %%
# %%time
casename = 'b.e13.B1850C5.ne30_g16.icesm13_ihesp.PI.002'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo',
    casename=casename,
    timespan=(1, 500),
    comp='atm',
    nproc=16,
    overwrite=True,
)

# %% [markdown]
# ## FV2

# %%
dirpath = '/glade/campaign/cgd/ppc/jiangzhu/iCESM1.3/b.e13.Bi1850C5.f19_g16.05'
case = x4c.Timeseries(dirpath, grid_dict={'atm': 'f19'})

# %%
# %%time
casename = 'b.e13.Bi1850C5.f19_g16.05'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo',
    casename=casename,
    timespan=(1, 50),
    slicing=True,
    comp='atm',
    nproc=16,
)

# %% [markdown]
# ## SE0.25

# %%
dirpath = '/glade/campaign/cgd/ppc/jiangzhu/paleoweather/b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003'
case = x4c.Timeseries(dirpath, grid_dict={'atm': 'ne120'})
# Out:
# >>> case.root_dir: /glade/campaign/cgd/ppc/jiangzhu/paleoweather/b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003
# >>> case.path_pattern: comp/proc/tseries/month_1/casename.mdl.h_str.vn.timespan.nc
# >>> case.grid_dict: {'atm': 'ne120', 'ocn': 'g16', 'lnd': 'ne120', 'rof': 'ne120', 'ice': 'g16'}
# >>> case.vars_info created

# %%
# %%time
casename = 'b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo',
    casename=casename,
    timespan=(41, 50),
    # vns=['TS'],
    comp='atm',
    nproc=16,
    overwrite=True,
    regrid=True,
)
# Out:
# >>> Generating climo for 193 variables:
# ['ADRAIN', 'ADSNOW', 'AEROD_v', 'ANRAIN', 'ANSNOW', 'AODDUST1', 'AODDUST3', 'AODVIS', 'AQRAIN', 'AQSNOW']
# ['AREI', 'AREL', 'AWNC', 'AWNI', 'BURDEN1', 'BURDEN2', 'BURDEN3', 'BURDENBC', 'BURDENDUST', 'BURDENPOM']
# ['BURDENSEASALT', 'BURDENSO4', 'BURDENSOA', 'CCN3', 'CDNUMC', 'CLDHGH', 'CLDICE', 'CLDLIQ', 'CLDLOW', 'CLDMED']
# ['CLDTOT', 'CLOUD', 'CMFMC', 'CMFMCDZM', 'DCQ', 'DMS_SRF', 'DTCOND', 'DTV', 'DTWR_H2O2', 'DTWR_H2SO4']
# ['DTWR_SO2', 'EMISCLD', 'FICE', 'FLDS', 'FLDSC', 'FLNS', 'FLNSC', 'FLNT', 'FLNTC', 'FLUT']
# ['FLUTC', 'FREQI', 'FREQL', 'FREQR', 'FREQS', 'FREQZM', 'FSDS', 'FSDSC', 'FSNS', 'FSNSC']
# ['FSNT', 'FSNTC', 'FSNTOA', 'FSNTOAC', 'FSUTOA', 'H216OI', 'H216OL', 'H216OR', 'H216OS', 'H216OV']
# ['H216Or', 'H216Os', 'H218OI', 'H218OL', 'H218OR', 'H218OS', 'H218OV', 'H218Or', 'H218Os', 'H2O2_SRF']
# ['H2OI', 'H2OL', 'H2OR', 'H2OS', 'H2OV', 'H2Or', 'H2Os', 'H2SO4_SRF', 'HDOI', 'HDOL']
# ['HDOR', 'HDOS', 'HDOV', 'HDOr', 'HDOs', 'ICEFRAC', 'ICIMR', 'ICWMR', 'IVT', 'IWC']
# ['LANDFRAC', 'LHFLX', 'LWCF', 'NUMICE', 'NUMLIQ', 'OCNFRAC', 'OMEGA', 'OMEGAT', 'PBLH', 'PCLDBOT']
# ['PCLDTOP', 'PHIS', 'PRECC', 'PRECL', 'PRECRC_H216Or', 'PRECRC_H218Or', 'PRECRC_H2Or', 'PRECRC_HDOr', 'PRECRL_H216OR', 'PRECRL_H218OR']
# ['PRECRL_H2OR', 'PRECRL_HDOR', 'PRECSC', 'PRECSC_H216Os', 'PRECSC_H218Os', 'PRECSC_H2Os', 'PRECSC_HDOs', 'PRECSL', 'PRECSL_H216OS', 'PRECSL_H218OS']
# ['PRECSL_H2OS', 'PRECSL_HDOS', 'PS', 'PSL', 'Q', 'QFLX', 'QRAINC', 'QRAINS', 'QREFHT', 'QRL']
# ['QRS', 'QSNOWC', 'QSNOWS', 'RELHUM', 'SHFLX', 'SNOWHICE', 'SNOWHLND', 'SO2_SRF', 'SOAG_SRF', 'SOLIN']
# ['SWCF', 'T', 'TAUGWX', 'TAUGWY', 'TAUX', 'TAUY', 'TGCLDCWP', 'TGCLDIWP', 'TGCLDLWP', 'TMQ']
# ['TREFHT', 'TREFHTMN', 'TREFHTMX', 'TS', 'TSMN', 'TSMX', 'U', 'U10', 'UU', 'V']
# ['VD01', 'VQ', 'VT', 'VU', 'VV', 'WGUSTD', 'WSUB', 'Z3', 'bc_a1_SRF', 'dst_a1_SRF']
# ['dst_a3_SRF', 'ncl_a1_SRF', 'ncl_a2_SRF', 'ncl_a3_SRF', 'num_a1_SRF', 'num_a2_SRF', 'num_a3_SRF', 'pom_a1_SRF', 'so4_a1_SRF', 'so4_a2_SRF']
# ['so4_a3_SRF', 'soa_a1_SRF', 'soa_a2_SRF']
# >>> nproc: 16
# Generating climo files: 100%|██████████| 193/193 [10:38<00:00,  3.31s/it]
# >>> 193 climo files created in: /glade/derecho/scratch/fengzhu/ADF/b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003/climo
# CPU times: user 166 ms, sys: 242 ms, total: 408 ms
# Wall time: 20min 39s

# %%
# %%time
casename = 'b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo_30yrs_noChunks',
    casename=casename,
    timespan=(21, 50),
    comp='atm',
    nproc=16,
    overwrite=True,
    regrid=True,
)
# Out:
# >>> output directory created at: /glade/derecho/scratch/fengzhu/ADF/b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003/climo_30yrs_noChunks
# >>> Generating climo for 193 variables:
# ['ADRAIN', 'ADSNOW', 'AEROD_v', 'ANRAIN', 'ANSNOW', 'AODDUST1', 'AODDUST3', 'AODVIS', 'AQRAIN', 'AQSNOW']
# ['AREI', 'AREL', 'AWNC', 'AWNI', 'BURDEN1', 'BURDEN2', 'BURDEN3', 'BURDENBC', 'BURDENDUST', 'BURDENPOM']
# ['BURDENSEASALT', 'BURDENSO4', 'BURDENSOA', 'CCN3', 'CDNUMC', 'CLDHGH', 'CLDICE', 'CLDLIQ', 'CLDLOW', 'CLDMED']
# ['CLDTOT', 'CLOUD', 'CMFMC', 'CMFMCDZM', 'DCQ', 'DMS_SRF', 'DTCOND', 'DTV', 'DTWR_H2O2', 'DTWR_H2SO4']
# ['DTWR_SO2', 'EMISCLD', 'FICE', 'FLDS', 'FLDSC', 'FLNS', 'FLNSC', 'FLNT', 'FLNTC', 'FLUT']
# ['FLUTC', 'FREQI', 'FREQL', 'FREQR', 'FREQS', 'FREQZM', 'FSDS', 'FSDSC', 'FSNS', 'FSNSC']
# ['FSNT', 'FSNTC', 'FSNTOA', 'FSNTOAC', 'FSUTOA', 'H216OI', 'H216OL', 'H216OR', 'H216OS', 'H216OV']
# ['H216Or', 'H216Os', 'H218OI', 'H218OL', 'H218OR', 'H218OS', 'H218OV', 'H218Or', 'H218Os', 'H2O2_SRF']
# ['H2OI', 'H2OL', 'H2OR', 'H2OS', 'H2OV', 'H2Or', 'H2Os', 'H2SO4_SRF', 'HDOI', 'HDOL']
# ['HDOR', 'HDOS', 'HDOV', 'HDOr', 'HDOs', 'ICEFRAC', 'ICIMR', 'ICWMR', 'IVT', 'IWC']
# ['LANDFRAC', 'LHFLX', 'LWCF', 'NUMICE', 'NUMLIQ', 'OCNFRAC', 'OMEGA', 'OMEGAT', 'PBLH', 'PCLDBOT']
# ['PCLDTOP', 'PHIS', 'PRECC', 'PRECL', 'PRECRC_H216Or', 'PRECRC_H218Or', 'PRECRC_H2Or', 'PRECRC_HDOr', 'PRECRL_H216OR', 'PRECRL_H218OR']
# ['PRECRL_H2OR', 'PRECRL_HDOR', 'PRECSC', 'PRECSC_H216Os', 'PRECSC_H218Os', 'PRECSC_H2Os', 'PRECSC_HDOs', 'PRECSL', 'PRECSL_H216OS', 'PRECSL_H218OS']
# ['PRECSL_H2OS', 'PRECSL_HDOS', 'PS', 'PSL', 'Q', 'QFLX', 'QRAINC', 'QRAINS', 'QREFHT', 'QRL']
# ['QRS', 'QSNOWC', 'QSNOWS', 'RELHUM', 'SHFLX', 'SNOWHICE', 'SNOWHLND', 'SO2_SRF', 'SOAG_SRF', 'SOLIN']
# ['SWCF', 'T', 'TAUGWX', 'TAUGWY', 'TAUX', 'TAUY', 'TGCLDCWP', 'TGCLDIWP', 'TGCLDLWP', 'TMQ']
# ['TREFHT', 'TREFHTMN', 'TREFHTMX', 'TS', 'TSMN', 'TSMX', 'U', 'U10', 'UU', 'V']
# ['VD01', 'VQ', 'VT', 'VU', 'VV', 'WGUSTD', 'WSUB', 'Z3', 'bc_a1_SRF', 'dst_a1_SRF']
# ['dst_a3_SRF', 'ncl_a1_SRF', 'ncl_a2_SRF', 'ncl_a3_SRF', 'num_a1_SRF', 'num_a2_SRF', 'num_a3_SRF', 'pom_a1_SRF', 'so4_a1_SRF', 'so4_a2_SRF']
# ['so4_a3_SRF', 'soa_a1_SRF', 'soa_a2_SRF']
# >>> nproc: 16
# Generating climo files:   0%|          | 0/193 [00:00<?, ?it/s]/glade/work/fengzhu/conda-envs/xpp-env/lib/python3.11/site-packages/xesmf/backend.py:56: UserWarning: Latitude is outside of [-90, 90]
#   warnings.warn('Latitude is outside of [-90, 90]')
# Generating climo files:  48%|████▊     | 92/193 [08:58<27:15, 16.19s/it]/glade/work/fengzhu/conda-envs/xpp-env/lib/python3.11/site-packages/xesmf/backend.py:56: UserWarning: Latitude is outside of [-90, 90]
#   warnings.warn('Latitude is outside of [-90, 90]')
# Generating climo files:  50%|████▉     | 96/193 [09:58<25:46, 15.94s/it]/glade/work/fengzhu/conda-envs/xpp-env/lib/python3.11/site-packages/xesmf/backend.py:56: UserWarning: Latitude is outside of [-90, 90]
#   warnings.warn('Latitude is outside of [-90, 90]')
# Generating climo files: 100%|██████████| 193/193 [26:26<00:00,  8.22s/it]
# >>> 193 climo files created in: /glade/derecho/scratch/fengzhu/ADF/b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003/climo_30yrs_noChunks
# CPU times: user 255 ms, sys: 257 ms, total: 513 ms
# Wall time: 43min 51s

# %%
# %%time
casename = 'b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo_30yrs',
    casename=casename,
    timespan=(21, 50),
    # vns=['TS'],
    comp='atm',
    nproc=16,
    overwrite=True,
    regrid=True,
    chunk_nt=10,
)
# Out:
# >>> Generating climo for 193 variables:
# ['ADRAIN', 'ADSNOW', 'AEROD_v', 'ANRAIN', 'ANSNOW', 'AODDUST1', 'AODDUST3', 'AODVIS', 'AQRAIN', 'AQSNOW']
# ['AREI', 'AREL', 'AWNC', 'AWNI', 'BURDEN1', 'BURDEN2', 'BURDEN3', 'BURDENBC', 'BURDENDUST', 'BURDENPOM']
# ['BURDENSEASALT', 'BURDENSO4', 'BURDENSOA', 'CCN3', 'CDNUMC', 'CLDHGH', 'CLDICE', 'CLDLIQ', 'CLDLOW', 'CLDMED']
# ['CLDTOT', 'CLOUD', 'CMFMC', 'CMFMCDZM', 'DCQ', 'DMS_SRF', 'DTCOND', 'DTV', 'DTWR_H2O2', 'DTWR_H2SO4']
# ['DTWR_SO2', 'EMISCLD', 'FICE', 'FLDS', 'FLDSC', 'FLNS', 'FLNSC', 'FLNT', 'FLNTC', 'FLUT']
# ['FLUTC', 'FREQI', 'FREQL', 'FREQR', 'FREQS', 'FREQZM', 'FSDS', 'FSDSC', 'FSNS', 'FSNSC']
# ['FSNT', 'FSNTC', 'FSNTOA', 'FSNTOAC', 'FSUTOA', 'H216OI', 'H216OL', 'H216OR', 'H216OS', 'H216OV']
# ['H216Or', 'H216Os', 'H218OI', 'H218OL', 'H218OR', 'H218OS', 'H218OV', 'H218Or', 'H218Os', 'H2O2_SRF']
# ['H2OI', 'H2OL', 'H2OR', 'H2OS', 'H2OV', 'H2Or', 'H2Os', 'H2SO4_SRF', 'HDOI', 'HDOL']
# ['HDOR', 'HDOS', 'HDOV', 'HDOr', 'HDOs', 'ICEFRAC', 'ICIMR', 'ICWMR', 'IVT', 'IWC']
# ['LANDFRAC', 'LHFLX', 'LWCF', 'NUMICE', 'NUMLIQ', 'OCNFRAC', 'OMEGA', 'OMEGAT', 'PBLH', 'PCLDBOT']
# ['PCLDTOP', 'PHIS', 'PRECC', 'PRECL', 'PRECRC_H216Or', 'PRECRC_H218Or', 'PRECRC_H2Or', 'PRECRC_HDOr', 'PRECRL_H216OR', 'PRECRL_H218OR']
# ['PRECRL_H2OR', 'PRECRL_HDOR', 'PRECSC', 'PRECSC_H216Os', 'PRECSC_H218Os', 'PRECSC_H2Os', 'PRECSC_HDOs', 'PRECSL', 'PRECSL_H216OS', 'PRECSL_H218OS']
# ['PRECSL_H2OS', 'PRECSL_HDOS', 'PS', 'PSL', 'Q', 'QFLX', 'QRAINC', 'QRAINS', 'QREFHT', 'QRL']
# ['QRS', 'QSNOWC', 'QSNOWS', 'RELHUM', 'SHFLX', 'SNOWHICE', 'SNOWHLND', 'SO2_SRF', 'SOAG_SRF', 'SOLIN']
# ['SWCF', 'T', 'TAUGWX', 'TAUGWY', 'TAUX', 'TAUY', 'TGCLDCWP', 'TGCLDIWP', 'TGCLDLWP', 'TMQ']
# ['TREFHT', 'TREFHTMN', 'TREFHTMX', 'TS', 'TSMN', 'TSMX', 'U', 'U10', 'UU', 'V']
# ['VD01', 'VQ', 'VT', 'VU', 'VV', 'WGUSTD', 'WSUB', 'Z3', 'bc_a1_SRF', 'dst_a1_SRF']
# ['dst_a3_SRF', 'ncl_a1_SRF', 'ncl_a2_SRF', 'ncl_a3_SRF', 'num_a1_SRF', 'num_a2_SRF', 'num_a3_SRF', 'pom_a1_SRF', 'so4_a1_SRF', 'so4_a2_SRF']
# ['so4_a3_SRF', 'soa_a1_SRF', 'soa_a2_SRF']
# >>> nproc: 16
# Generating climo files: 100%|██████████| 193/193 [57:40<00:00, 17.93s/it]
# >>> 193 climo files created in: /glade/derecho/scratch/fengzhu/ADF/b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003/climo_30yrs
# CPU times: user 485 ms, sys: 303 ms, total: 788 ms
# Wall time: 1h 21min 16s

# %%
# %%time
casename = 'b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo_50yrs',
    casename=casename,
    timespan=(1, 50),
    vns=['TS'],
    comp='atm',
    nproc=1,
    overwrite=True,
    regrid=True,
)
# Out:
# >>> Generating climo for 1 variables:
# ['TS']
# Generating climo files: 100%|██████████| 1/1 [00:12<00:00, 12.86s/it]
# >>> 1 climo files created in: /glade/derecho/scratch/fengzhu/ADF/b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003/climo_50yrs
# CPU times: user 13.2 s, sys: 1.29 s, total: 14.5 s
# Wall time: 12.9 s

# %%
# %%time
casename = 'b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003'
case.gen_climo(
    output_dirpath=f'/glade/derecho/scratch/fengzhu/ADF/{casename}/climo_50yrs',
    casename=casename,
    timespan=(1, 50),
    # vns=['TS'],
    comp='atm',
    nproc=64,
    overwrite=True,
    regrid=True,
)
# Out:
# >>> Generating climo for 193 variables:
# ['ADRAIN', 'ADSNOW', 'AEROD_v', 'ANRAIN', 'ANSNOW', 'AODDUST1', 'AODDUST3', 'AODVIS', 'AQRAIN', 'AQSNOW']
# ['AREI', 'AREL', 'AWNC', 'AWNI', 'BURDEN1', 'BURDEN2', 'BURDEN3', 'BURDENBC', 'BURDENDUST', 'BURDENPOM']
# ['BURDENSEASALT', 'BURDENSO4', 'BURDENSOA', 'CCN3', 'CDNUMC', 'CLDHGH', 'CLDICE', 'CLDLIQ', 'CLDLOW', 'CLDMED']
# ['CLDTOT', 'CLOUD', 'CMFMC', 'CMFMCDZM', 'DCQ', 'DMS_SRF', 'DTCOND', 'DTV', 'DTWR_H2O2', 'DTWR_H2SO4']
# ['DTWR_SO2', 'EMISCLD', 'FICE', 'FLDS', 'FLDSC', 'FLNS', 'FLNSC', 'FLNT', 'FLNTC', 'FLUT']
# ['FLUTC', 'FREQI', 'FREQL', 'FREQR', 'FREQS', 'FREQZM', 'FSDS', 'FSDSC', 'FSNS', 'FSNSC']
# ['FSNT', 'FSNTC', 'FSNTOA', 'FSNTOAC', 'FSUTOA', 'H216OI', 'H216OL', 'H216OR', 'H216OS', 'H216OV']
# ['H216Or', 'H216Os', 'H218OI', 'H218OL', 'H218OR', 'H218OS', 'H218OV', 'H218Or', 'H218Os', 'H2O2_SRF']
# ['H2OI', 'H2OL', 'H2OR', 'H2OS', 'H2OV', 'H2Or', 'H2Os', 'H2SO4_SRF', 'HDOI', 'HDOL']
# ['HDOR', 'HDOS', 'HDOV', 'HDOr', 'HDOs', 'ICEFRAC', 'ICIMR', 'ICWMR', 'IVT', 'IWC']
# ['LANDFRAC', 'LHFLX', 'LWCF', 'NUMICE', 'NUMLIQ', 'OCNFRAC', 'OMEGA', 'OMEGAT', 'PBLH', 'PCLDBOT']
# ['PCLDTOP', 'PHIS', 'PRECC', 'PRECL', 'PRECRC_H216Or', 'PRECRC_H218Or', 'PRECRC_H2Or', 'PRECRC_HDOr', 'PRECRL_H216OR', 'PRECRL_H218OR']
# ['PRECRL_H2OR', 'PRECRL_HDOR', 'PRECSC', 'PRECSC_H216Os', 'PRECSC_H218Os', 'PRECSC_H2Os', 'PRECSC_HDOs', 'PRECSL', 'PRECSL_H216OS', 'PRECSL_H218OS']
# ['PRECSL_H2OS', 'PRECSL_HDOS', 'PS', 'PSL', 'Q', 'QFLX', 'QRAINC', 'QRAINS', 'QREFHT', 'QRL']
# ['QRS', 'QSNOWC', 'QSNOWS', 'RELHUM', 'SHFLX', 'SNOWHICE', 'SNOWHLND', 'SO2_SRF', 'SOAG_SRF', 'SOLIN']
# ['SWCF', 'T', 'TAUGWX', 'TAUGWY', 'TAUX', 'TAUY', 'TGCLDCWP', 'TGCLDIWP', 'TGCLDLWP', 'TMQ']
# ['TREFHT', 'TREFHTMN', 'TREFHTMX', 'TS', 'TSMN', 'TSMX', 'U', 'U10', 'UU', 'V']
# ['VD01', 'VQ', 'VT', 'VU', 'VV', 'WGUSTD', 'WSUB', 'Z3', 'bc_a1_SRF', 'dst_a1_SRF']
# ['dst_a3_SRF', 'ncl_a1_SRF', 'ncl_a2_SRF', 'ncl_a3_SRF', 'num_a1_SRF', 'num_a2_SRF', 'num_a3_SRF', 'pom_a1_SRF', 'so4_a1_SRF', 'so4_a2_SRF']
# ['so4_a3_SRF', 'soa_a1_SRF', 'soa_a2_SRF']
# >>> nproc: 16
# Generating climo files:  37%|███▋      | 71/193 [02:15<03:52,  1.91s/it]Process ForkPoolWorker-6:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-8:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/Github/x4c/x4c/case.py:285, in Timeseries.gen_climo(self, output_dirpath, comp, casename, timespan, vns, adjust_month, nproc, slicing, regrid, overwrite)
#     283     with mp.Pool(processes=nproc) as p:
#     284         arg_list = [(v, output_dirpath, comp, casename, timespan, adjust_month, slicing, regrid, overwrite) for v in vns]
# --> 285         p.starmap(self.save_climo, tqdm(arg_list, total=len(vns), desc=f'Generating climo files'))
#     287 utils.p_success(f'>>> {len(vns)} climo files created in: {output_dirpath}')
#
# File /glade/work/fengzhu/conda-envs/xpp-env/lib/python3.11/multiprocessing/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File /glade/work/fengzhu/conda-envs/xpp-env/lib/python3.11/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /glade/work/fengzhu/conda-envs/xpp-env/lib/python3.11/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /glade/work/fengzhu/conda-envs/xpp-env/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /glade/work/fengzhu/conda-envs/xpp-env/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %%
dirpath = '/glade/campaign/cgd/ppc/jiangzhu/paleoweather/b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003'
case = x4c.Timeseries(dirpath, grid_dict={'atm': 'ne120'})
case.vars_info
# Out:
# >>> case.root_dir: /glade/campaign/cgd/ppc/jiangzhu/paleoweather/b.e13.B1850C5.ne120_g16.icesm13_ihesp.PI.003
# >>> case.path_pattern: comp/proc/tseries/month_1/casename.mdl.h_str.vn.timespan.nc
# >>> case.grid_dict: {'atm': 'ne120', 'ocn': 'g16', 'lnd': 'ne120', 'rof': 'ne120', 'ice': 'g16'}
# >>> case.vars_info created
# {('ADRAIN', 'atm'): ('atm', 'cam', 'h0'),
#  ('ADSNOW', 'atm'): ('atm', 'cam', 'h0'),
#  ('AEROD_v', 'atm'): ('atm', 'cam', 'h0'),
#  ('ANRAIN', 'atm'): ('atm', 'cam', 'h0'),
#  ('ANSNOW', 'atm'): ('atm', 'cam', 'h0'),
#  ('AODDUST1', 'atm'): ('atm', 'cam', 'h0'),
#  ('AODDUST3', 'atm'): ('atm', 'cam', 'h0'),
#  ('AODVIS', 'atm'): ('atm', 'cam', 'h0'),
#  ('AQRAIN', 'atm'): ('atm', 'cam', 'h0'),
#  ('AQSNOW', 'atm'): ('atm', 'cam', 'h0'),
#  ('AREI', 'atm'): ('atm', 'cam', 'h0'),
#  ('AREL', 'atm'): ('atm', 'cam', 'h0'),
#  ('AWNC', 'atm'): ('atm', 'cam', 'h0'),
#  ('AWNI', 'atm'): ('atm', 'cam', 'h0'),
#  ('BURDEN1', 'atm'): ('atm', 'cam', 'h0'),
#  ('BURDEN2', 'atm'): ('atm', 'cam', 'h0'),
#  ('BURDEN3', 'atm'): ('atm', 'cam', 'h0'),
#  ('BURDENBC', 'atm'): ('atm', 'cam', 'h0'),
#  ('BURDENDUST', 'atm'): ('atm', 'cam', 'h0'),
#  ('BURDENPOM', 'atm'): ('atm', 'cam', 'h0'),
#  ('BURDENSEASALT', 'atm'): ('atm', 'cam', 'h0'),
#  ('BURDENSO4', 'atm'): ('atm', 'cam', 'h0'),
#  ('BURDENSOA', 'atm'): ('atm', 'cam', 'h0'),
#  ('CCN3', 'atm'): ('atm', 'cam', 'h0'),
#  ('CDNUMC', 'atm'): ('atm', 'cam', 'h0'),
#  ('CLDHGH', 'atm'): ('atm', 'cam', 'h0'),
#  ('CLDICE', 'atm'): ('atm', 'cam', 'h0'),
#  ('CLDLIQ', 'atm'): ('atm', 'cam', 'h0'),
#  ('CLDLOW', 'atm'): ('atm', 'cam', 'h0'),
#  ('CLDMED', 'atm'): ('atm', 'cam', 'h0'),
#  ('CLDTOT', 'atm'): ('atm', 'cam', 'h0'),
#  ('CLOUD', 'atm'): ('atm', 'cam', 'h0'),
#  ('CMFMC', 'atm'): ('atm', 'cam', 'h0'),
#  ('CMFMCDZM', 'atm'): ('atm', 'cam', 'h0'),
#  ('DCQ', 'atm'): ('atm', 'cam', 'h0'),
#  ('DMS_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('DTCOND', 'atm'): ('atm', 'cam', 'h0'),
#  ('DTV', 'atm'): ('atm', 'cam', 'h0'),
#  ('DTWR_H2O2', 'atm'): ('atm', 'cam', 'h0'),
#  ('DTWR_H2SO4', 'atm'): ('atm', 'cam', 'h0'),
#  ('DTWR_SO2', 'atm'): ('atm', 'cam', 'h0'),
#  ('EMISCLD', 'atm'): ('atm', 'cam', 'h0'),
#  ('FICE', 'atm'): ('atm', 'cam', 'h0'),
#  ('FLDS', 'atm'): ('atm', 'cam', 'h0'),
#  ('FLDSC', 'atm'): ('atm', 'cam', 'h0'),
#  ('FLNS', 'atm'): ('atm', 'cam', 'h0'),
#  ('FLNSC', 'atm'): ('atm', 'cam', 'h0'),
#  ('FLNT', 'atm'): ('atm', 'cam', 'h0'),
#  ('FLNTC', 'atm'): ('atm', 'cam', 'h0'),
#  ('FLUT', 'atm'): ('atm', 'cam', 'h0'),
#  ('FLUTC', 'atm'): ('atm', 'cam', 'h0'),
#  ('FREQI', 'atm'): ('atm', 'cam', 'h0'),
#  ('FREQL', 'atm'): ('atm', 'cam', 'h0'),
#  ('FREQR', 'atm'): ('atm', 'cam', 'h0'),
#  ('FREQS', 'atm'): ('atm', 'cam', 'h0'),
#  ('FREQZM', 'atm'): ('atm', 'cam', 'h0'),
#  ('FSDS', 'atm'): ('atm', 'cam', 'h0'),
#  ('FSDSC', 'atm'): ('atm', 'cam', 'h0'),
#  ('FSNS', 'atm'): ('atm', 'cam', 'h0'),
#  ('FSNSC', 'atm'): ('atm', 'cam', 'h0'),
#  ('FSNT', 'atm'): ('atm', 'cam', 'h0'),
#  ('FSNTC', 'atm'): ('atm', 'cam', 'h0'),
#  ('FSNTOA', 'atm'): ('atm', 'cam', 'h0'),
#  ('FSNTOAC', 'atm'): ('atm', 'cam', 'h0'),
#  ('FSUTOA', 'atm'): ('atm', 'cam', 'h0'),
#  ('H216OI', 'atm'): ('atm', 'cam', 'h0'),
#  ('H216OL', 'atm'): ('atm', 'cam', 'h0'),
#  ('H216OR', 'atm'): ('atm', 'cam', 'h0'),
#  ('H216OS', 'atm'): ('atm', 'cam', 'h0'),
#  ('H216OV', 'atm'): ('atm', 'cam', 'h0'),
#  ('H216Or', 'atm'): ('atm', 'cam', 'h0'),
#  ('H216Os', 'atm'): ('atm', 'cam', 'h0'),
#  ('H218OI', 'atm'): ('atm', 'cam', 'h0'),
#  ('H218OL', 'atm'): ('atm', 'cam', 'h0'),
#  ('H218OR', 'atm'): ('atm', 'cam', 'h0'),
#  ('H218OS', 'atm'): ('atm', 'cam', 'h0'),
#  ('H218OV', 'atm'): ('atm', 'cam', 'h0'),
#  ('H218Or', 'atm'): ('atm', 'cam', 'h0'),
#  ('H218Os', 'atm'): ('atm', 'cam', 'h0'),
#  ('H2O2_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('H2OI', 'atm'): ('atm', 'cam', 'h0'),
#  ('H2OL', 'atm'): ('atm', 'cam', 'h0'),
#  ('H2OR', 'atm'): ('atm', 'cam', 'h0'),
#  ('H2OS', 'atm'): ('atm', 'cam', 'h0'),
#  ('H2OV', 'atm'): ('atm', 'cam', 'h0'),
#  ('H2Or', 'atm'): ('atm', 'cam', 'h0'),
#  ('H2Os', 'atm'): ('atm', 'cam', 'h0'),
#  ('H2SO4_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('HDOI', 'atm'): ('atm', 'cam', 'h0'),
#  ('HDOL', 'atm'): ('atm', 'cam', 'h0'),
#  ('HDOR', 'atm'): ('atm', 'cam', 'h0'),
#  ('HDOS', 'atm'): ('atm', 'cam', 'h0'),
#  ('HDOV', 'atm'): ('atm', 'cam', 'h0'),
#  ('HDOr', 'atm'): ('atm', 'cam', 'h0'),
#  ('HDOs', 'atm'): ('atm', 'cam', 'h0'),
#  ('ICEFRAC', 'atm'): ('atm', 'cam', 'h0'),
#  ('ICIMR', 'atm'): ('atm', 'cam', 'h0'),
#  ('ICWMR', 'atm'): ('atm', 'cam', 'h0'),
#  ('IVT', 'atm'): ('atm', 'cam', 'h0'),
#  ('IWC', 'atm'): ('atm', 'cam', 'h0'),
#  ('LANDFRAC', 'atm'): ('atm', 'cam', 'h0'),
#  ('LHFLX', 'atm'): ('atm', 'cam', 'h0'),
#  ('LWCF', 'atm'): ('atm', 'cam', 'h0'),
#  ('NUMICE', 'atm'): ('atm', 'cam', 'h0'),
#  ('NUMLIQ', 'atm'): ('atm', 'cam', 'h0'),
#  ('OCNFRAC', 'atm'): ('atm', 'cam', 'h0'),
#  ('OMEGA', 'atm'): ('atm', 'cam', 'h0'),
#  ('OMEGAT', 'atm'): ('atm', 'cam', 'h0'),
#  ('PBLH', 'atm'): ('atm', 'cam', 'h0'),
#  ('PCLDBOT', 'atm'): ('atm', 'cam', 'h0'),
#  ('PCLDTOP', 'atm'): ('atm', 'cam', 'h0'),
#  ('PHIS', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECC', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECL', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECRC_H216Or', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECRC_H218Or', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECRC_H2Or', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECRC_HDOr', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECRL_H216OR', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECRL_H218OR', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECRL_H2OR', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECRL_HDOR', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECSC', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECSC_H216Os', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECSC_H218Os', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECSC_H2Os', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECSC_HDOs', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECSL', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECSL_H216OS', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECSL_H218OS', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECSL_H2OS', 'atm'): ('atm', 'cam', 'h0'),
#  ('PRECSL_HDOS', 'atm'): ('atm', 'cam', 'h0'),
#  ('PS', 'atm'): ('atm', 'cam', 'h0'),
#  ('PSL', 'atm'): ('atm', 'cam', 'h0'),
#  ('Q', 'atm'): ('atm', 'cam', 'h0'),
#  ('QFLX', 'atm'): ('atm', 'cam', 'h0'),
#  ('QRAINC', 'atm'): ('atm', 'cam', 'h0'),
#  ('QRAINS', 'atm'): ('atm', 'cam', 'h0'),
#  ('QREFHT', 'atm'): ('atm', 'cam', 'h0'),
#  ('QRL', 'atm'): ('atm', 'cam', 'h0'),
#  ('QRS', 'atm'): ('atm', 'cam', 'h0'),
#  ('QSNOWC', 'atm'): ('atm', 'cam', 'h0'),
#  ('QSNOWS', 'atm'): ('atm', 'cam', 'h0'),
#  ('RELHUM', 'atm'): ('atm', 'cam', 'h0'),
#  ('SHFLX', 'atm'): ('atm', 'cam', 'h0'),
#  ('SNOWHICE', 'atm'): ('atm', 'cam', 'h0'),
#  ('SNOWHLND', 'atm'): ('atm', 'cam', 'h0'),
#  ('SO2_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('SOAG_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('SOLIN', 'atm'): ('atm', 'cam', 'h0'),
#  ('SWCF', 'atm'): ('atm', 'cam', 'h0'),
#  ('T', 'atm'): ('atm', 'cam', 'h0'),
#  ('TAUGWX', 'atm'): ('atm', 'cam', 'h0'),
#  ('TAUGWY', 'atm'): ('atm', 'cam', 'h0'),
#  ('TAUX', 'atm'): ('atm', 'cam', 'h0'),
#  ('TAUY', 'atm'): ('atm', 'cam', 'h0'),
#  ('TGCLDCWP', 'atm'): ('atm', 'cam', 'h0'),
#  ('TGCLDIWP', 'atm'): ('atm', 'cam', 'h0'),
#  ('TGCLDLWP', 'atm'): ('atm', 'cam', 'h0'),
#  ('TMQ', 'atm'): ('atm', 'cam', 'h0'),
#  ('TREFHT', 'atm'): ('atm', 'cam', 'h0'),
#  ('TREFHTMN', 'atm'): ('atm', 'cam', 'h0'),
#  ('TREFHTMX', 'atm'): ('atm', 'cam', 'h0'),
#  ('TS', 'atm'): ('atm', 'cam', 'h0'),
#  ('TSMN', 'atm'): ('atm', 'cam', 'h0'),
#  ('TSMX', 'atm'): ('atm', 'cam', 'h0'),
#  ('U', 'atm'): ('atm', 'cam', 'h0'),
#  ('U10', 'atm'): ('atm', 'cam', 'h0'),
#  ('UU', 'atm'): ('atm', 'cam', 'h0'),
#  ('V', 'atm'): ('atm', 'cam', 'h0'),
#  ('VD01', 'atm'): ('atm', 'cam', 'h0'),
#  ('VQ', 'atm'): ('atm', 'cam', 'h0'),
#  ('VT', 'atm'): ('atm', 'cam', 'h0'),
#  ('VU', 'atm'): ('atm', 'cam', 'h0'),
#  ('VV', 'atm'): ('atm', 'cam', 'h0'),
#  ('WGUSTD', 'atm'): ('atm', 'cam', 'h0'),
#  ('WSUB', 'atm'): ('atm', 'cam', 'h0'),
#  ('Z3', 'atm'): ('atm', 'cam', 'h0'),
#  ('bc_a1_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('dst_a1_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('dst_a3_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('ncl_a1_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('ncl_a2_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('ncl_a3_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('num_a1_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('num_a2_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('num_a3_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('pom_a1_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('so4_a1_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('so4_a2_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('so4_a3_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('soa_a1_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('soa_a2_SRF', 'atm'): ('atm', 'cam', 'h0'),
#  ('FYarea', 'ice'): ('ice', 'cice', 'h'),
#  ('Qref', 'ice'): ('ice', 'cice', 'h'),
#  ('Tair', 'ice'): ('ice', 'cice', 'h'),
#  ('Tref', 'ice'): ('ice', 'cice', 'h'),
#  ('Tsfc', 'ice'): ('ice', 'cice', 'h'),
#  ('aeroiceint001', 'ice'): ('ice', 'cice', 'h'),
#  ('aeroiceint002', 'ice'): ('ice', 'cice', 'h'),
#  ('aeroiceint003', 'ice'): ('ice', 'cice', 'h'),
#  ('aeroicessl001', 'ice'): ('ice', 'cice', 'h'),
#  ('aeroicessl002', 'ice'): ('ice', 'cice', 'h'),
#  ('aeroicessl003', 'ice'): ('ice', 'cice', 'h'),
#  ('aerosnoint001', 'ice'): ('ice', 'cice', 'h'),
#  ('aerosnoint002', 'ice'): ('ice', 'cice', 'h'),
#  ('aerosnoint003', 'ice'): ('ice', 'cice', 'h'),
#  ('aerosnossl001', 'ice'): ('ice', 'cice', 'h'),
#  ('aerosnossl002', 'ice'): ('ice', 'cice', 'h'),
#  ('aerosnossl003', 'ice'): ('ice', 'cice', 'h'),
#  ('aice', 'ice'): ('ice', 'cice', 'h'),
#  ('aicen001', 'ice'): ('ice', 'cice', 'h'),
#  ('aicen002', 'ice'): ('ice', 'cice', 'h'),
#  ('aicen003', 'ice'): ('ice', 'cice', 'h'),
#  ('aicen004', 'ice'): ('ice', 'cice', 'h'),
#  ('aicen005', 'ice'): ('ice', 'cice', 'h'),
#  ('aisnap', 'ice'): ('ice', 'cice', 'h'),
#  ('alidf', 'ice'): ('ice', 'cice', 'h'),
#  ('alidr', 'ice'): ('ice', 'cice', 'h'),
#  ('alvdf', 'ice'): ('ice', 'cice', 'h'),
#  ('alvdr', 'ice'): ('ice', 'cice', 'h'),
#  ('apond001', 'ice'): ('ice', 'cice', 'h'),
#  ('apond002', 'ice'): ('ice', 'cice', 'h'),
#  ('apond003', 'ice'): ('ice', 'cice', 'h'),
#  ('apond004', 'ice'): ('ice', 'cice', 'h'),
#  ('apond005', 'ice'): ('ice', 'cice', 'h'),
#  ('congel', 'ice'): ('ice', 'cice', 'h'),
#  ('daidtd', 'ice'): ('ice', 'cice', 'h'),
#  ('daidtt', 'ice'): ('ice', 'cice', 'h'),
#  ('dardg1dt', 'ice'): ('ice', 'cice', 'h'),
#  ('dardg2dt', 'ice'): ('ice', 'cice', 'h'),
#  ('divu', 'ice'): ('ice', 'cice', 'h'),
#  ('dvidtd', 'ice'): ('ice', 'cice', 'h'),
#  ('dvidtt', 'ice'): ('ice', 'cice', 'h'),
#  ('dvirdgdt', 'ice'): ('ice', 'cice', 'h'),
#  ('evap', 'ice'): ('ice', 'cice', 'h'),
#  ('evap_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('faero_atm001', 'ice'): ('ice', 'cice', 'h'),
#  ('faero_atm002', 'ice'): ('ice', 'cice', 'h'),
#  ('faero_atm003', 'ice'): ('ice', 'cice', 'h'),
#  ('faero_ocn001', 'ice'): ('ice', 'cice', 'h'),
#  ('faero_ocn002', 'ice'): ('ice', 'cice', 'h'),
#  ('faero_ocn003', 'ice'): ('ice', 'cice', 'h'),
#  ('fcondtop_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('fhocn', 'ice'): ('ice', 'cice', 'h'),
#  ('fhocn_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_Qref001', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_Qref002', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_Qref003', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_atm001', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_atm002', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_atm003', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_evap001', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_evap002', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_evap003', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_ocn001', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_ocn002', 'ice'): ('ice', 'cice', 'h'),
#  ('fiso_ocn003', 'ice'): ('ice', 'cice', 'h'),
#  ('flat', 'ice'): ('ice', 'cice', 'h'),
#  ('flat_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('flwdn', 'ice'): ('ice', 'cice', 'h'),
#  ('flwup', 'ice'): ('ice', 'cice', 'h'),
#  ('flwup_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('frazil', 'ice'): ('ice', 'cice', 'h'),
#  ('fresh', 'ice'): ('ice', 'cice', 'h'),
#  ('fresh_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('fs', 'ice'): ('ice', 'cice', 'h'),
#  ('fsalt', 'ice'): ('ice', 'cice', 'h'),
#  ('fsalt_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('fsens', 'ice'): ('ice', 'cice', 'h'),
#  ('fsens_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('fsurf_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('fswabs', 'ice'): ('ice', 'cice', 'h'),
#  ('fswabs_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('fswdn', 'ice'): ('ice', 'cice', 'h'),
#  ('fswthru', 'ice'): ('ice', 'cice', 'h'),
#  ('fswthru_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('fswup', 'ice'): ('ice', 'cice', 'h'),
#  ('hi', 'ice'): ('ice', 'cice', 'h'),
#  ('hisnap', 'ice'): ('ice', 'cice', 'h'),
#  ('hs', 'ice'): ('ice', 'cice', 'h'),
#  ('iage', 'ice'): ('ice', 'cice', 'h'),
#  ('ice_present', 'ice'): ('ice', 'cice', 'h'),
#  ('meltb', 'ice'): ('ice', 'cice', 'h'),
#  ('meltl', 'ice'): ('ice', 'cice', 'h'),
#  ('melts', 'ice'): ('ice', 'cice', 'h'),
#  ('meltt', 'ice'): ('ice', 'cice', 'h'),
#  ('opening', 'ice'): ('ice', 'cice', 'h'),
#  ('qi', 'ice'): ('ice', 'cice', 'h'),
#  ('qs', 'ice'): ('ice', 'cice', 'h'),
#  ('rain', 'ice'): ('ice', 'cice', 'h'),
#  ('rain_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('shear', 'ice'): ('ice', 'cice', 'h'),
#  ('sig1', 'ice'): ('ice', 'cice', 'h'),
#  ('sig2', 'ice'): ('ice', 'cice', 'h'),
#  ('snoice', 'ice'): ('ice', 'cice', 'h'),
#  ('snow', 'ice'): ('ice', 'cice', 'h'),
#  ('snow_ai', 'ice'): ('ice', 'cice', 'h'),
#  ('strairx', 'ice'): ('ice', 'cice', 'h'),
#  ('strairy', 'ice'): ('ice', 'cice', 'h'),
#  ('strcorx', 'ice'): ('ice', 'cice', 'h'),
#  ('strcory', 'ice'): ('ice', 'cice', 'h'),
#  ('strength', 'ice'): ('ice', 'cice', 'h'),
#  ('strintx', 'ice'): ('ice', 'cice', 'h'),
#  ('strinty', 'ice'): ('ice', 'cice', 'h'),
#  ('strocnx', 'ice'): ('ice', 'cice', 'h'),
#  ('strocny', 'ice'): ('ice', 'cice', 'h'),
#  ('transix', 'ice'): ('ice', 'cice', 'h'),
#  ('transiy', 'ice'): ('ice', 'cice', 'h'),
#  ('trsig', 'ice'): ('ice', 'cice', 'h'),
#  ('uvel', 'ice'): ('ice', 'cice', 'h'),
#  ('vicen001', 'ice'): ('ice', 'cice', 'h'),
#  ('vicen002', 'ice'): ('ice', 'cice', 'h'),
#  ('vicen003', 'ice'): ('ice', 'cice', 'h'),
#  ('vicen004', 'ice'): ('ice', 'cice', 'h'),
#  ('vicen005', 'ice'): ('ice', 'cice', 'h'),
#  ('vvel', 'ice'): ('ice', 'cice', 'h'),
#  ('BCDEP', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('BTRAN', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('BUILDHEAT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('DSTDEP', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('DSTFLXT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('EFLX_DYNBAL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('EFLX_LH_TOT_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('EFLX_LH_TOT_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('ELAI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('ERRH2O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('ERRH2OSNO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('ERRSEB', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('ERRSOI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('ERRSOL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('ESAI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FCEV', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FCOV', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FCTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FGEV', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FGR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FGR12', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FGR_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FGR_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FIRA', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FIRA_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FIRA_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FIRE', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FLDS', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FPSN', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSA', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSAT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSA_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSA_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSDS', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSDSND', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSDSNDLN', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSDSNI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSDSVD', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSDSVDLN', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSDSVI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSH', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSH_G', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSH_NODYNLNDUSE', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSH_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSH_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSH_V', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSM', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSM_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSM_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSNO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSOIEQ', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSRND', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSRNDLN', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSRNI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSRVD', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSRVDLN', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('FSRVI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('GC_HEAT1', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('GC_ICE1', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('GC_LIQ1', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OCAN', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OCAN_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OCAN_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OCAN_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OSNO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OSNO_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OSNO_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OSNO_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OSNO_TOP', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OSOI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OSOI_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OSOI_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('H2OSOI_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('HC', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('HCSOI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('HEAT_FROM_AC', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('LAISHA', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('LAISUN', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('OCDEP', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('PBOT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('PCO2', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('Q2M', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('Q2M_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('Q2M_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('Q2M_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QBOT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QBOT_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QBOT_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QBOT_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QCHARGE', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QDRAI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QDRAI_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QDRAI_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QDRAI_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QDRIP', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QDRIP_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QDRIP_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QDRIP_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QFLX_ICE_DYNBAL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QFLX_LIQ_DYNBAL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QINFL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QINFL_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QINFL_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QINFL_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QINTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QINTR_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QINTR_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QINTR_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QIRRIG', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QMELT_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QMELT_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QMELT_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QOVER', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QOVER_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QOVER_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QOVER_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QRGWL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QRGWL_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QRGWL_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QRGWL_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QRUNOFF', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QRUNOFF_NODYNLNDUSE', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QRUNOFF_NODYNLNDUSE_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QRUNOFF_NODYNLNDUSE_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QRUNOFF_NODYNLNDUSE_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QRUNOFF_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QRUNOFF_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QSNOMELT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QSNWCPICE', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QSNWCPICE_NODYNLNDUSE', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QSOIL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QSOIL_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QSOIL_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QSOIL_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QVEGE', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QVEGE_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QVEGE_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QVEGE_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QVEGT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QVEGT_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QVEGT_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('QVEGT_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RAIN', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RAIN_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RAIN_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RAIN_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RAW1', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RAW2', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCANV_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCANV_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCANV_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSHA_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSHA_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSHA_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSHA_PSN_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSHA_PSN_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSHA_PSN_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSUN_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSUN_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSUN_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSUN_PSN_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSUN_PSN_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RCELLSUN_PSN_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RH2M', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RH2M_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RH2M_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLB', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLITTER', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_DIAG_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_DIAG_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_DIAG_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_PSN_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_PSN_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_PSN_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_STDY_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_STDY_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSHA_STDY_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_DIAG_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_DIAG_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_DIAG_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_PSN_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_PSN_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_PSN_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_STDY_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_STDY_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RLWSUN_STDY_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RSFC', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RSSHA', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RSSUN', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RXYLEM_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RXYLEM_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('RXYLEM_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SABG', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SABV', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOBCMCL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOBCMSL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNODSTMCL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNODSTMSL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOOCMCL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOOCMSL', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOW', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOWDP', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOWICE', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOWICE_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOWICE_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOWICE_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOWLIQ', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOWLIQ_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOWLIQ_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOWLIQ_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOW_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOW_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOW_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOW_SINKS', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SNOW_SOURCES', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SOILICE', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SOILLIQ', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SOILLIQICE_10CM_H218O', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SOILLIQICE_10CM_H2OTR', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SOILLIQICE_10CM_HDO', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SOILWATER_10CM', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SoilAlpha', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('SoilAlpha_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TAUX', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TAUY', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TBOT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TBUILD', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TG', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TG_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TG_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('THBOT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TLAI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TLAKE', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TREFMNAV', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TREFMNAV_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TREFMNAV_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TREFMXAV', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TREFMXAV_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TREFMXAV_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TSA', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TSAI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TSA_R', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TSA_U', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TSOI', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TSOI_10CM', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TSOI_ICE', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('TV', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('U10', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('URBAN_AC', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('URBAN_HEAT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('WA', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('WASTEHEAT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('WIND', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('WT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('ZBOT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('ZWT', 'lnd'): ('lnd', 'clm2', 'h0'),
#  ('ADVS', 'ocn'): ('ocn', 'pop', 'h'),
#  ('ADVS_ISOP', 'ocn'): ('ocn', 'pop', 'h'),
#  ('ADVS_SUBM', 'ocn'): ('ocn', 'pop', 'h'),
#  ('ADVT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('ADVT_ISOP', 'ocn'): ('ocn', 'pop', 'h'),
#  ('ADVT_SUBM', 'ocn'): ('ocn', 'pop', 'h'),
#  ('BSF', 'ocn'): ('ocn', 'pop', 'h'),
#  ('DIA_DEPTH', 'ocn'): ('ocn', 'pop', 'h'),
#  ('EVAP_16O_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('EVAP_18O_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('EVAP_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('EVAP_HDO_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('FW', 'ocn'): ('ocn', 'pop', 'h'),
#  ('FvICE_R18O', 'ocn'): ('ocn', 'pop', 'h'),
#  ('FvICE_RHDO', 'ocn'): ('ocn', 'pop', 'h'),
#  ('FvPER_R18O', 'ocn'): ('ocn', 'pop', 'h'),
#  ('FvPER_RHDO', 'ocn'): ('ocn', 'pop', 'h'),
#  ('HBLT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('HDIFS', 'ocn'): ('ocn', 'pop', 'h'),
#  ('HDIFT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('HLS_SUBM', 'ocn'): ('ocn', 'pop', 'h'),
#  ('HMXL', 'ocn'): ('ocn', 'pop', 'h'),
#  ('HOR_DIFF', 'ocn'): ('ocn', 'pop', 'h'),
#  ('IAGE', 'ocn'): ('ocn', 'pop', 'h'),
#  ('IFRAC', 'ocn'): ('ocn', 'pop', 'h'),
#  ('INT_DEPTH', 'ocn'): ('ocn', 'pop', 'h'),
#  ('IOFF_16O_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('IOFF_18O_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('IOFF_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('IOFF_HDO_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('KAPPA_ISOP', 'ocn'): ('ocn', 'pop', 'h'),
#  ('KAPPA_THIC', 'ocn'): ('ocn', 'pop', 'h'),
#  ('KVMIX', 'ocn'): ('ocn', 'pop', 'h'),
#  ('KVMIX_M', 'ocn'): ('ocn', 'pop', 'h'),
#  ('LWDN_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('LWUP_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('MELTH_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('MELT_16O_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('MELT_18O_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('MELT_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('MELT_HDO_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('MOC', 'ocn'): ('ocn', 'pop', 'h'),
#  ('N_HEAT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('N_SALT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('PD', 'ocn'): ('ocn', 'pop', 'h'),
#  ('PREC_16O_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('PREC_18O_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('PREC_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('PREC_HDO_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('PV', 'ocn'): ('ocn', 'pop', 'h'),
#  ('Q', 'ocn'): ('ocn', 'pop', 'h'),
#  ('QFLUX', 'ocn'): ('ocn', 'pop', 'h'),
#  ('QSW_HBL', 'ocn'): ('ocn', 'pop', 'h'),
#  ('QSW_HTP', 'ocn'): ('ocn', 'pop', 'h'),
#  ('R18O', 'ocn'): ('ocn', 'pop', 'h'),
#  ('RESID_S', 'ocn'): ('ocn', 'pop', 'h'),
#  ('RESID_T', 'ocn'): ('ocn', 'pop', 'h'),
#  ('RHDO', 'ocn'): ('ocn', 'pop', 'h'),
#  ('RHO', 'ocn'): ('ocn', 'pop', 'h'),
#  ('RHO_VINT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('ROFF_16O_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('ROFF_18O_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('ROFF_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('ROFF_HDO_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SALT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SALT_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SENH_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SFWF', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SFWF_WRST', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SHF', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SHF_QSW', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SNOW_F', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SSH', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SSH2', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SU', 'ocn'): ('ocn', 'pop', 'h'),
#  ('SV', 'ocn'): ('ocn', 'pop', 'h'),
#  ('TAUX', 'ocn'): ('ocn', 'pop', 'h'),
#  ('TAUX2', 'ocn'): ('ocn', 'pop', 'h'),
#  ('TAUY', 'ocn'): ('ocn', 'pop', 'h'),
#  ('TAUY2', 'ocn'): ('ocn', 'pop', 'h'),
#  ('TBLT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('TEMP', 'ocn'): ('ocn', 'pop', 'h'),
#  ('TFW_S', 'ocn'): ('ocn', 'pop', 'h'),
#  ('TFW_T', 'ocn'): ('ocn', 'pop', 'h'),
#  ('TLT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('TMXL', 'ocn'): ('ocn', 'pop', 'h'),
#  ('TPOWER', 'ocn'): ('ocn', 'pop', 'h'),
#  ('UES', 'ocn'): ('ocn', 'pop', 'h'),
#  ('UET', 'ocn'): ('ocn', 'pop', 'h'),
#  ('UISOP', 'ocn'): ('ocn', 'pop', 'h'),
#  ('USUBM', 'ocn'): ('ocn', 'pop', 'h'),
#  ('UVEL', 'ocn'): ('ocn', 'pop', 'h'),
#  ('UVEL2', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VDC_S', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VDC_T', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VISOP', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VNS', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VNS_ISOP', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VNS_SUBM', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VNT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VNT_ISOP', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VNT_SUBM', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VSUBM', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VVC', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VVEL', 'ocn'): ('ocn', 'pop', 'h'),
#  ('VVEL2', 'ocn'): ('ocn', 'pop', 'h'),
#  ('WISOP', 'ocn'): ('ocn', 'pop', 'h'),
#  ('WSUBM', 'ocn'): ('ocn', 'pop', 'h'),
#  ('WTS', 'ocn'): ('ocn', 'pop', 'h'),
#  ('WTT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('WVEL', 'ocn'): ('ocn', 'pop', 'h'),
#  ('WVEL2', 'ocn'): ('ocn', 'pop', 'h'),
#  ('XBLT', 'ocn'): ('ocn', 'pop', 'h'),
#  ('XMXL', 'ocn'): ('ocn', 'pop', 'h'),
#  ('dTEMP_NEG_2D', 'ocn'): ('ocn', 'pop', 'h'),
#  ('dTEMP_POS_2D', 'ocn'): ('ocn', 'pop', 'h'),
#  ('QCHANR_ICE', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHANR_ICE_16O', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHANR_ICE_18O', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHANR_ICE_HDO', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHANR_LIQ', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHANR_LIQ_16O', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHANR_LIQ_18O', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHANR_LIQ_HDO', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHOCNR_ICE', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHOCNR_ICE_16O', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHOCNR_ICE_18O', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHOCNR_ICE_HDO', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHOCNR_LIQ', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHOCNR_LIQ_16O', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHOCNR_LIQ_18O', 'rof'): ('rof', 'mosart', 'h0'),
#  ('QCHOCNR_LIQ_HDO', 'rof'): ('rof', 'mosart', 'h0')}
