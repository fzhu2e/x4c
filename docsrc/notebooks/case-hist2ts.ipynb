# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir('/glade/u/home/fengzhu/Github/x4c/docsrc/notebooks')
import numpy as np
import x4c
print(x4c.__version__)
# Out:
# 2024.8.5.15

# %%
dirpath = '/glade/campaign/univ/uazn0034/fengzhu/CESM_output/archive/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2'
case = x4c.History(dirpath, casename='b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2')
# Out:
# >>> case.root_dir: /glade/campaign/univ/uazn0034/fengzhu/CESM_output/archive/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2
# >>> case.casename: b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2
# >>> case.comps_info: {'atm': ('cam', 'h0'), 'ocn': ('pop', 'h'), 'lnd': ('clm2', 'h0'), 'ice': ('cice', 'h'), 'rof': ('rtm', 'h0')}
# >>> case.paths["atm"] created
# >>> case.paths["ocn"] created
# >>> case.paths["lnd"] created
# >>> case.paths["ice"] created
# >>> case.paths["rof"] created
# >>> case.vns["atm"] created
# >>> case.vns["ocn"] created
# >>> case.vns["lnd"] created
# >>> case.vns["ice"] created
# >>> case.vns["rof"] created

# %%
path_pattern = 'comp/hist/casename.mdl.h_str.date.nc'
paths = x4c.utils.find_paths(case.root_dir, path_pattern, comp='ocn', mdl='pop', h_str='h', verbose=True,
                             avoid_list=['nday1', 'once'])
# Out:
# path_pattern: ocn/*/*.pop.h.*[0-9].nc

# %%
case.get_paths('ocn', timespan=(5501, 5550))
# Out:
# ['/glade/campaign/univ/uazn0034/fengzhu/CESM_output/archive/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2/ocn/hist/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2.pop.h.5501-01.nc',
#  '/glade/campaign/univ/uazn0034/fengzhu/CESM_output/archive/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2/ocn/hist/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2.pop.h.5501-02.nc',
#  '/glade/campaign/univ/uazn0034/fengzhu/CESM_output/archive/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2/ocn/hist/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2.pop.h.5501-03.nc',
#  '/glade/campaign/univ/uazn0034/fengzhu/CESM_output/archive/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2/ocn/hist/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2.pop.h.5501-04.nc',
# ...

# %%
# %%time

case.gen_ts(
    # comps={'atm': ['TS', 'T'], 'ocn': ['SALT']},
    comps={'atm': ['TS']},
    output_dirpath='/glade/campaign/univ/uazn0034/fengzhu/CESM_output/timeseries',
    scratch_dirpath=f'/glade/derecho/scratch/fengzhu/x4c/gen_ts/test',
    timespan=(5501, 5550),
    timestep=50,
    nproc=1,
    overwrite=True,
    compression=1,
)
# Out:
# >>> Processing component: atm
# >>> Processing timespan: (5501, 5550)
# ...
# Merging variables: 100%|██████████| 1/1 [00:02<00:00,  2.87s/it]
# Moving generated files
# from: /glade/derecho/scratch/fengzhu/x4c/gen_ts/test
# Moving generated filesiv/uazn0034/fengzhu/CESM_output/timeseries: 0it [00:00, ?it/s]
# from: /glade/derecho/scratch/fengzhu/x4c/gen_ts/test
# to: /glade/campaign/univ/uazn0034/fengzhu/CESM_output/timeseries: 0it [00:00, ?it/s]
# CPU times: user 1.02 s, sys: 391 ms, total: 1.41 s
# Wall time: 2min 30s

# %%
# %%time

case.gen_ts(
    # comps={'atm': ['TS', 'T'], 'ocn': ['SALT']},
    comps={'atm': ['TS'], 'ocn': ['SSH']},
    output_dirpath=os.path.join('/glade/campaign/univ/uazn0034/fengzhu/CESM_output/timeseries', case.casename),
    scratch_dirpath=f'/glade/derecho/scratch/fengzhu/x4c/gen_ts/test',
    timespan=(5501, 5501),
    timestep=1,
    nproc=1,
    overwrite=True,
    compression=1,
)
# Out:
# >>> Processing component: atm
# >>> Processing timespan: (5501, 5501)
# ...
# Merging variables: 100%|██████████| 1/1 [00:00<00:00, 10.46it/s]
# >>> Processing component: ocn
# >>> Processing timespan: (5501, 5501)
# ...
# Merging variables: 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]
# >>> Postprocessing component: atm
# Moving generated files
# from: /glade/derecho/scratch/fengzhu/x4c/gen_ts/test
# to: /glade/campaign/univ/uazn0034/fengzhu/CESM_output/timeseries/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2
# Moving generated files [00:00<?, ?it/s]
# from: /glade/derecho/scratch/fengzhu/x4c/gen_ts/test
# to: /glade/campaign/univ/uazn0034/fengzhu/CESM_output/timeseries/b.e13.B1850C5.ne16_g16.icesm131_d18O_fixer.Miocene.1.5xCO2.branch_461.2
# : 100%|██████████| 1/1 [00:00<00:00, 706.47it/s]
# >>> Postprocessing component: ocn
# Moving generated files
# from: /glade/derecho/scratch/fengzhu/x4c/gen_ts/test
# ...
